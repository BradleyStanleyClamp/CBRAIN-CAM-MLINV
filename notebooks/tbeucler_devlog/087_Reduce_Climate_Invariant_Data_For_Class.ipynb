# %% [markdown]
# tgb - 2022/03/31 - The goal of this notebook is to:
# - Reduce CBRAIN data so that it fits in the Google Colab RAM (12Gb)
# - Rename the variables so that they are more intuitive for the course's students

# %% [markdown]
# # Import libraries and load data

# %%
path_data = '/DFS-L/DATA/pritchard/tbeucler/SPCAM/SPCAM_PHYS/'

# %%
from cbrain.climate_invariant import *
from cbrain.climate_invariant_utils import *
# Out:
# /nfspool-0/home/tbeucler/CBRAIN-CAM/notebooks/tbeucler_devlog

# %%
path_train = path_data + '2021_03_18_O3_TRAIN_M4K.nc'

# %%
research_data = xr.open_dataset(path_train)

# %%
research_data
# Out:
# <xarray.Dataset>
# Dimensions:    (sample: 47177728, var_names: 214)
# Coordinates:
#   * var_names  (var_names) object 'QBP' 'QBP' 'QBP' 'QBP' ... 'QRS' 'QRS' 'QRS'
#     time       (sample) int64 ...
#     lat        (sample) float64 ...
#     lon        (sample) float64 ...
# Dimensions without coordinates: sample
# Data variables:
#     vars       (sample, var_names) float64 ...

# %% [markdown]
# # Select index in time

# %%
t_index_1_week = 7*64*128*48

# %%
t_index_1_week
# Out:
# 2752512

# %%
47177728/t_index_1_week # Number of weeks in dataset
# Out:
# 17.139880952380953

# %%
research_data['time'][t_index_1_week]
# Out:
# <xarray.DataArray 'time' ()>
# array(336)
# Coordinates:
#     time     int64 ...
#     lat      float64 ...
#     lon      float64 ...

# %%
research_data['time'][t_index_1_week-1]
# Out:
# <xarray.DataArray 'time' ()>
# array(335)
# Coordinates:
#     time     int64 ...
#     lat      float64 ...
#     lon      float64 ...

# %% [markdown]
# # Select right variables

# %%
research_data['vars'].shape
# Out:
# (47177728, 214)

# %%
nam = research_data['var_names'].values

# %%
nam[:30]
# Out:
# array(['QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP',
#        'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP',
#        'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP', 'QBP',
#        'QBP', 'QBP', 'QBP'], dtype=object)

# %%
nam[30:60]
# Out:
# array(['TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP',
#        'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP',
#        'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP', 'TBP',
#        'TBP', 'TBP', 'TBP'], dtype=object)

# %%
nam[90:94]
# Out:
# array(['PS', 'SOLIN', 'SHFLX', 'LHFLX'], dtype=object)

# %%
nam[124:154]
# Out:
# array(['TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND',
#        'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND',
#        'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND',
#        'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND',
#        'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND',
#        'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND', 'TPHYSTND'],
#       dtype=object)

# %%
Q = research_data['vars'][:t_index_1_week,:30]

# %%
T = research_data['vars'][:t_index_1_week,30:60]

# %%
PS = research_data['vars'][:t_index_1_week,90]
S0 = research_data['vars'][:t_index_1_week,91]
SHF = research_data['vars'][:t_index_1_week,92]
LHF = research_data['vars'][:t_index_1_week,93]

# %%
SUBGRID = research_data['vars'][:t_index_1_week,124:154]

# %% [markdown]
# # Organize and save data array

# %%
sample = np.arange(0,t_index_1_week)

# %%
sample
# Out:
# array([      0,       1,       2, ..., 2752509, 2752510, 2752511])

# %%
research_data['lev']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /DFS-L/DATA/pritchard/tbeucler/Miniconda3_2021_04_12/miniconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1163         try:
# -> 1164             variable = self._variables[name]
#    1165         except KeyError:
#
# KeyError: 'lev'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-d73522c08104> in <module>
# ----> 1 research_data['lev']
#
# /DFS-L/DATA/pritchard/tbeucler/Miniconda3_2021_04_12/miniconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1252
#    1253         if hashable(key):
# -> 1254             return self._construct_dataarray(key)
#    1255         else:
# ...

# %%
Qda = xr.DataArray(
data = Q.values,
dims = ['sample','pressure'],
coords = {'sample': sample,'pressure'},
attrs = {
    'units': 'g/kg',
    'name': 'Specific Humidity'
}
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-fffcf749bfd9> in <module>
#       5 attrs = {
#       6     'units': 'g/kg',
# ----> 7     'name': 'Specific Humidity'
#       8 }
#       9 )
#
# /DFS-L/DATA/pritchard/tbeucler/Miniconda3_2021_04_12/miniconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/core/dataarray.py in __init__(self, data, coords, dims, name, attrs, indexes, fastpath)
#     342             data = _check_data_shape(data, coords, dims)
#     343             data = as_compatible_data(data)
# --> 344             coords, dims = _infer_coords_and_dims(data.shape, coords, dims)
#     345             variable = Variable(dims, data, attrs, fastpath=True)
#     346             indexes = dict(
#
# ...

# %%
import numpy as np
import xarray as xr
import pandas as pd

# create dummy dataframe
times = pd.date_range(start='2000-01-01',freq='1H',periods=6)

# create dataset
ds = xr.Dataset({
    'SWdown': xr.DataArray(
                data   = np.random.random(6),   # enter data here
                dims   = ['time'],
                coords = {'time': times},
                attrs  = {
                    '_FillValue': -999.9,
                    'units'     : 'W/m2'
                    }
                ),
    'LWdown': xr.DataArray(
                data   = np.random.random(6),   # enter data here
                dims   = ['time'],
                coords = {'time': times},
                attrs  = {
                    '_FillValue': -999.9,
                    'units'     : 'W/m2'
                    }
                )
            },
        attrs = {'example_attr': 'this is a global attribute'}
    )
